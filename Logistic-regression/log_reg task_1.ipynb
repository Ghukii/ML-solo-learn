# %% [markdown]
# # Задание:
# Прогнозирование вероятности диабета у пациентов
#
# # Описание:
# Вы работаете в медицинской клинике и вам предоставлен набор данных о пациентах, включающий информацию о различных медицинских параметрах и наличии или отсутствии диабета. Ваша задача - построить модель логистической регрессии для прогнозирования вероятности наличия диабета у пациентов.

# %% [markdown]
# # Шаги:
#
# Импорт данных: Загрузите данные в DataFrame (например, из CSV-файла).
#
# Исследование данных: Изучите данные, чтобы понять их структуру, типы признаков, наличие пропущенных значений и т. д.
#
# Подготовка данных: Проведите необходимую предобработку данных, включая заполнение пропущенных значений, кодирование категориальных признаков и масштабирование признаков.
#
# Разделение данных: Разделите данные на обучающую и тестовую выборки.
#
# Обучение модели: Обучите модель логистической регрессии на обучающих данных.
#
# Оценка модели: Оцените производительность модели на тестовых данных, используя метрики классификации, такие как точность, полнота, F1-мера и ROC AUC.
#
# Интерпретация результатов: Проанализируйте коэффициенты модели, чтобы понять, какие медицинские параметры оказывают наибольшее влияние на вероятность наличия диабета.
#
# # Дополнительные задачи:
#
# Попробуйте улучшить модель, используя методы выбора признаков, регуляризацию или инженерию признаков.
# Исследуйте важность признаков и попробуйте объяснить, какие медицинские параметры оказывают наибольшее влияние на вероятность наличия диабета.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import seaborn as sns

# %%
df = pd.read_csv('diabetes.csv')
df.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# 5                     0.201   30        0
# 6                     0.248   26        1
# 7                     0.134   29        0
# 8                     0.158   53        1
# 9                     0.232   54        1

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_37bb1_row0_col0, #T_37bb1_row1_col1, #T_37bb1_row2_col2, #T_37bb1_row3_col3, #T_37bb1_row4_col4, #T_37bb1_row5_col5, #T_37bb1_row6_col6, #T_37bb1_row7_col7, #T_37bb1_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_37bb1_row0_col1 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_37bb1_row0_col2 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_37bb1_row0_col3, #T_37bb1_row7_col4 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_37bb1_row0_col4, #T_37bb1_row0_col5, #T_37bb1_row0_col6, #T_37bb1_row2_col8, #T_37bb1_row3_col0, #T_37bb1_row3_col1, #T_37bb1_row3_col7, #T_37bb1_row6_col2, #T_37bb1_row7_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_37bb1_row0_col7 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_37bb1_row0_col8, #T_37bb1_row1_col6 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_37bb1_row1_col0 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_37bb1_row1_col2, #T_37bb1_row6_col8 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_37bb1_row1_col3 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_37bb1_row1_col4 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_37bb1_row1_col5, #T_37bb1_row3_col6 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_37bb1_row1_col7 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_37bb1_row1_col8 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_37bb1_row2_col0, #T_37bb1_row7_col2 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_37bb1_row2_col1 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_37bb1_row2_col3 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_37bb1_row2_col4 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_37bb1_row2_col5, #T_37bb1_row6_col3 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_37bb1_row2_col6 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_37bb1_row2_col7 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_37bb1_row3_col2, #T_37bb1_row5_col1 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_37bb1_row3_col4 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_37bb1_row3_col5 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_37bb1_row3_col8 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_37bb1_row4_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_37bb1_row4_col1 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_37bb1_row4_col2 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_37bb1_row4_col3 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_37bb1_row4_col5 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_37bb1_row4_col6 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_37bb1_row4_col7, #T_37bb1_row7_col6 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_37bb1_row4_col8 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_37bb1_row5_col0 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_37bb1_row5_col2, #T_37bb1_row5_col4 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_37bb1_row5_col3 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_37bb1_row5_col6, #T_37bb1_row8_col3 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_37bb1_row5_col7 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_37bb1_row5_col8 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_37bb1_row6_col0 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_37bb1_row6_col1 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_37bb1_row6_col4 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_37bb1_row6_col5 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_37bb1_row6_col7 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_37bb1_row7_col0 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_37bb1_row7_col1 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_37bb1_row7_col5 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_37bb1_row7_col8 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_37bb1_row8_col0, #T_37bb1_row8_col5 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_37bb1_row8_col1 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_37bb1_row8_col2 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_37bb1_row8_col4 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_37bb1_row8_col6 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_37bb1_row8_col7 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# </style>
# <table id="T_37bb1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_37bb1_level0_col0" class="col_heading level0 col0" >Pregnancies</th>
#       <th id="T_37bb1_level0_col1" class="col_heading level0 col1" >Glucose</th>
#       <th id="T_37bb1_level0_col2" class="col_heading level0 col2" >BloodPressure</th>
#       <th id="T_37bb1_level0_col3" class="col_heading level0 col3" >SkinThickness</th>
#       <th id="T_37bb1_level0_col4" class="col_heading level0 col4" >Insulin</th>
#       <th id="T_37bb1_level0_col5" class="col_heading level0 col5" >BMI</th>
#       <th id="T_37bb1_level0_col6" class="col_heading level0 col6" >DiabetesPedigreeFunction</th>
#       <th id="T_37bb1_level0_col7" class="col_heading level0 col7" >Age</th>
#       <th id="T_37bb1_level0_col8" class="col_heading level0 col8" >Outcome</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_37bb1_level0_row0" class="row_heading level0 row0" >Pregnancies</th>
#       <td id="T_37bb1_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_37bb1_row0_col1" class="data row0 col1" >0.129459</td>
#       <td id="T_37bb1_row0_col2" class="data row0 col2" >0.141282</td>
#       <td id="T_37bb1_row0_col3" class="data row0 col3" >-0.081672</td>
#       <td id="T_37bb1_row0_col4" class="data row0 col4" >-0.073535</td>
#       <td id="T_37bb1_row0_col5" class="data row0 col5" >0.017683</td>
#       <td id="T_37bb1_row0_col6" class="data row0 col6" >-0.033523</td>
#       <td id="T_37bb1_row0_col7" class="data row0 col7" >0.544341</td>
#       <td id="T_37bb1_row0_col8" class="data row0 col8" >0.221898</td>
#     </tr>
#     <tr>
#       <th id="T_37bb1_level0_row1" class="row_heading level0 row1" >Glucose</th>
#       <td id="T_37bb1_row1_col0" class="data row1 col0" >0.129459</td>
#       <td id="T_37bb1_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_37bb1_row1_col2" class="data row1 col2" >0.152590</td>
#       <td id="T_37bb1_row1_col3" class="data row1 col3" >0.057328</td>
#       <td id="T_37bb1_row1_col4" class="data row1 col4" >0.331357</td>
#       <td id="T_37bb1_row1_col5" class="data row1 col5" >0.221071</td>
#       <td id="T_37bb1_row1_col6" class="data row1 col6" >0.137337</td>
#       <td id="T_37bb1_row1_col7" class="data row1 col7" >0.263514</td>
#       <td id="T_37bb1_row1_col8" class="data row1 col8" >0.466581</td>
#     </tr>
#     <tr>
#       <th id="T_37bb1_level0_row2" class="row_heading level0 row2" >BloodPressure</th>
#       <td id="T_37bb1_row2_col0" class="data row2 col0" >0.141282</td>
#       <td id="T_37bb1_row2_col1" class="data row2 col1" >0.152590</td>
#       <td id="T_37bb1_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_37bb1_row2_col3" class="data row2 col3" >0.207371</td>
#       <td id="T_37bb1_row2_col4" class="data row2 col4" >0.088933</td>
#       <td id="T_37bb1_row2_col5" class="data row2 col5" >0.281805</td>
#       <td id="T_37bb1_row2_col6" class="data row2 col6" >0.041265</td>
#       <td id="T_37bb1_row2_col7" class="data row2 col7" >0.239528</td>
#       <td id="T_37bb1_row2_col8" class="data row2 col8" >0.065068</td>
#     </tr>
#     <tr>
#       <th id="T_37bb1_level0_row3" class="row_heading level0 row3" >SkinThickness</th>
#       <td id="T_37bb1_row3_col0" class="data row3 col0" >-0.081672</td>
#       <td id="T_37bb1_row3_col1" class="data row3 col1" >0.057328</td>
#       <td id="T_37bb1_row3_col2" class="data row3 col2" >0.207371</td>
#       <td id="T_37bb1_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_37bb1_row3_col4" class="data row3 col4" >0.436783</td>
#       <td id="T_37bb1_row3_col5" class="data row3 col5" >0.392573</td>
#       <td id="T_37bb1_row

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
X = df[['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']].values
Y = df['Outcome'].values
# Out:
# array([[  6.   , 148.   ,  72.   , ...,  33.6  ,   0.627,  50.   ],
#        [  1.   ,  85.   ,  66.   , ...,  26.6  ,   0.351,  31.   ],
#        [  8.   , 183.   ,  64.   , ...,  23.3  ,   0.672,  32.   ],
#        ...,
#        [  5.   , 121.   ,  72.   , ...,  26.2  ,   0.245,  30.   ],
#        [  1.   , 126.   ,  60.   , ...,  30.1  ,   0.349,  47.   ],
#        [  1.   ,  93.   ,  70.   , ...,  30.4  ,   0.315,  23.   ]])
